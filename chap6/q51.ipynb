# %%
#参考サイト
#https://qiita.com/ground0state/items/155b77f4c07e1a509a14
import pandas as pd
import re
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
#カンマ区切りはread_csv()、タブ区切りはread_tabel()を使用
df = pd.read_table("newsCorpora.csv",
                                   header=None,
                                   names=("ID","TITLE","URL","PUBLISHER","CATEGORY","STORY","HOSTNAME","TIME"),
                                   sep="\t",
                                   encoding="UTF-8")
instance=df.query("PUBLISHER in ['Reuters','Huffington Post','Businessweek','Contactmusic.com','Daily Mail']")
print(instance)
instance_loc=instance.loc[:,["CATEGORY","TITLE"]]

category_list=instance.CATEGORY.values.tolist()
title_list=instance.TITLE.values.tolist()


for i,title in enumerate(title_list):
    title=title.lower()
    title=re.sub('[!"#$%&\'\\\\()*+,-./:;<=>?@[\\]^_`{|}~「」〔〕“”〈〉『』【】＆＊・（）＄＃＠。、？！｀＋￥％]',"",title)#記号類を削除
    title=re.sub(" [0-9]+"," 0",title)#数字を0に置き換え
    title=re.sub(" [0-9]+(.+?) "," \\1 ",title)#3-appleのような表現をappleに置き換え
    title=re.sub("million|thouzand|billion|trillion|quadrillion","0",title)#位を示す数詞を0に置き換え
    title_list[i]=title
        #word=re.sub("[0-9]+","0",word)
#print(title_list)
#print(len(title_list))

#カテゴリ名を数値に変換
str_to_int={"b":0,"t":1,"e":2,"m":3}
for i,category in enumerate(category_list):
    category_list[i]=str_to_int[category]  
#print(category_list)

#データ量を軽くするため、出現頻度の低い単語を無視
vec_tfidf=TfidfVectorizer(min_df=0.0001)
X=vec_tfidf.fit_transform(title_list)



#print(type(X))
df=pd.DataFrame(X.toarray(), columns=vec_tfidf.get_feature_names())#pandas.df型に変換
df["CATEGORY"]=category_list#カテゴリ名を末尾に追加
train,valid=train_test_split(df,test_size=0.20)#訓練データと検証データに分割
valid,test=train_test_split(valid,test_size=0.25)#検証データを、検証データと評価データに再分割


#ファイル出力
train.to_csv("train.feature.txt", sep="\t",header=False,index=False)
valid.to_csv("valid.feature.txt", sep="\t",header=False,index=False)
test.to_csv("test,feature.txt", sep="\t",header=False,index=False)

print(valid)
#ID タイトル URL 情報元 カテゴリ  ストーリー URLホスト名 日付
# Out:
#             ID                                              TITLE  \
# 12          13       Europe reaches crunch point on banking union
# 13          14  ECB FOCUS-Stronger euro drowns out ECB's messa...
# 19          20  Euro Anxieties Wane as Bunds Top Treasuries, S...
# 20          21  Noyer Says Strong Euro Creates Unwarranted Eco...
# 29          30  REFILE-Bad loan triggers key feature in ECB ba...
# ...        ...                                                ...
# 422300  422819     UN: Ebola Could Eventually Infect 20000 People
# 422301  422820  Ebola toll tops 1550, continues to accelerate ...
# 422302  422821  UPDATE 1-Ebola toll tops 1550, outbreak accele...
# 422309  422828  Ebola Cases May Surpass 20000, WHO Says in Upd...
# 422319  422838  Air France suspends flights to Ebola-hit Sierr...
#
#                                                       URL        PUBLISHER  \
# 12      http://in.reuters.com/article/2014/03/10/eu-ba...          Reuters
# 13      http://in.reuters.com/article/2014/03/10/ecb-p...          Reuters
# 19      http://www.businessweek.com/news/2014-03-10/ge...     Businessweek
# 20      http://www.businessweek.com/news/2014-03-10/no...     Businessweek
# 29      http://in.reuters.com/article/2014/03/10/euroz...          Reuters
# ...                                                   ...              ...
# 422300  http://www.huffingtonpost.com/2014/08/28/ebola...  Huffington Post
# 422301  http://in.reuters.com/article/2014/08/28/healt...          Reuters
# 422302  http://in.reuters.com/article/2014/08/28/healt...          Reuters
# 422309  http://www.businessweek.com/news/2014-08-28/eb...     Businessweek
# 422319  http://www.dailymail.co.uk/travel/travel_news/...       Daily Mail
#
#        CATEGORY                          STORY                HOSTNAME  \
# 12            b  dPhGU51DcrolUIMxbRm0InaHGA2XM          in.reuters.com
# 13            b  dPhGU51DcrolUIMxbRm0InaHGA2XM          in.reuters.com
# 19            b  dPhGU51DcrolUIMxbRm0InaHGA2XM    www.businessweek.com
# 20            b  dPhGU51DcrolUIMxbRm0InaHGA2XM    www.businessweek.com
# 29            b  dPhGU51DcrolUIMxbRm0InaHGA2XM          in.reuters.com
# ...         ...                            ...                     ...
# 422300        m  dhhnSHVoyA7ENBM3boDX_D_-3PV6M  www.huffingtonpost.com
# 422301        m  dhhnSHVoyA7ENBM3boDX_D_-3PV6M          in.reuters.com
# 422302        m  dhhnSHVoyA7ENBM3boDX_D_-3PV6M          in.reuters.com
# 422309        m  dhhnSHVoyA7ENBM3boDX_D_-3PV6M    www.businessweek.com
# 422319        m  dhhnSHVoyA7ENBM3boDX_D_-3PV6M     www.dailymail.co.uk
#
#                  TIME
# 12      1394470501755
# 13      1394470501948
# 19      1394470503148
# 20      1394470503366
# 29      1394470505070
# ...               ...
# 422300  1409228423333
# 422301  1409228423827
# 422302  1409228424525
# 422309  1409228426943
# 422319  1409228430383
#
# [13340 rows x 8 columns]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-2b159299ac92> in <module>
#      51 #ファイル出力
#      52 train.to_csv("train.feature.txt", sep="\t",header=False,index=False)
# ---> 53 valid.to_csv("valid.feature.txt", sep="\t",header=False,index=False)
#      54 test.to_csv("test,feature.txt", sep="\t",header=False,index=False)
#      55
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors)
#    3168             decimal=decimal,
#    3169         )
# -> 3170         formatter.save()
#    3171
#    3172         if path_or_buf is None:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/csvs.py in save(self)
#     204             )
#     205
# --> 206             self._save()
#     207
#     208         finally:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/csvs.py in _save(self)
#     326                 break
#     327
# --> 328             self._save_chunk(start_i, end_i)
#     329
#     330     def _save_chunk(self, start_i: int, end_i: int) -> None:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/csvs.py in _save_chunk(self, start_i, end_i)
#     339         for i in range(len(blocks)):
#     340             b = blocks[i]
# --> 341             d = b.to_native_types(
#     342                 na_rep=self.na_rep,
#     343                 float_format=self.float_format,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/blocks.py in to_native_types(self, na_rep, float_format, decimal, quoting, **kwargs)
#    1949
#    1950             if not quoting:
# -> 1951                 values = values.astype(str)
#    1952             else:
#    1953                 values = np.array(values, dtype="object")
#
# KeyboardInterrupt:
