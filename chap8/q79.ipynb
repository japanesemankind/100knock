# %%
from torch.utils.data import Dataset
from torch import nn
import torch
from torch.utils.data import DataLoader
#from q71 import SLPNet
from q73 import NewsDataset
from q74 import load_Dataloader
import time
from torch.nn import functional as F

class SLPNet(nn.Module):
    def __init__(self, input_size, output_size,mid_size):        
        super().__init__()
        self.fc = nn.Linear(input_size,mid_size,bias=False)        
        self.fc2= nn.Linear(mid_size, mid_size)
        self.fc3=nn.Linear(mid_size, output_size)
        #正則化とドロップアウトを追加
        self.dropout = nn.Dropout(0.3)
        self.bn = nn.BatchNorm1d(mid_size)
        nn.init.normal_(self.fc.weight, 0.0, 1.0)  # 正規乱数で重みを初期化
        
    def forward(self, x):
        x = F.relu(self.fc(x))
        #x = F.relu(self.fc2(x))
        #x = self.dropout(x)
        x = F.relu(self.bn(x))
        x = self.dropout(x)
        x = F.relu(self.fc3(x))        
#        x = self.relu(x)
#        x = self.dropout(x)
        
        return x


def calculate_loss_and_accuracy(model, criterion, loader, device):
    model.eval()
    loss = 0.0
    total = 0
    correct = 0
    with torch.no_grad():
        for inputs, labels in loader:
            inputs = inputs.to(device)
            labels = labels.to(device)
            outputs = model(inputs)
            loss += criterion(outputs, labels).item()
            pred = torch.argmax(outputs, dim=-1)
            total += len(inputs)
            correct += (pred == labels).sum().item()
            
    return loss / len(loader), correct / total


def train_model(dataloader_train, dataloader_valid,model, criterion, optimizer, num_epochs, device=None):
    # GPUに送る
    model.to(device)

    
    # 学習
    log_train = []
    log_valid = []
    
    scheduler =torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, num_epochs, eta_min=1e-5, last_epoch=-1)
    #cosカーブに従って、学習率を変化させる
    #引数:オプティマイザ、半周期の長さ、最小学習率
    
    #scheduler = torch.optim.lr_scheduler.StepLR(optimizer,num_epochs/5,0.5)
    for epoch in range(num_epochs):
        # 開始時刻の記録
        s_time = time.time()
        
        # 訓練モードに設定 
        model.train()
        
        for inputs, labels in dataloader_train:
            # 勾配をゼロで初期化
            optimizer.zero_grad()
            # 順伝播 + 誤差逆伝播 + 重み更新
            inputs = inputs.to(device)
            labels = labels.to(device)
            outputs = model.forward(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            
        # 損失と正解率の算出
        loss_train, acc_train = calculate_loss_and_accuracy(model, criterion, dataloader_train, device)
        loss_valid, acc_valid = calculate_loss_and_accuracy(model, criterion, dataloader_valid, device)
        log_train.append([loss_train, acc_train])
        log_valid.append([loss_valid, acc_valid])
            
        # チェックポイントの保存
#        torch.save({'epoch': epoch, 'model_state_dict': model.state_dict(), 'optimizer_state_dict': optimizer.state_dict()}, f'checkpoint{epoch + 1}.pt')
            
        # 終了時刻の記録
        e_time = time.time()
        
        # ログを出力
        print(f'epoch: {epoch + 1}, loss_train: {loss_train:.4f}, accuracy_train: {acc_train:.4f}, loss_valid: {loss_valid:.4f}, accuracy_valid: {acc_valid:.4f}, {(e_time - s_time):.4f}sec') 
        
#        if epoch > 2 and log_valid[epoch - 4][0] <= log_valid[epoch - 3][0] <= log_valid[epoch - 2][0] <= log_valid[epoch - 1][0] <= log_valid[epoch][0]:
#            break
        scheduler.step()
    return {'train': log_train, 'valid': log_valid}

if __name__=="__main__":

    
    model = SLPNet(300, 4,200)# モデルの定義    
    criterion = nn.CrossEntropyLoss()# 損失関数の定義
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)# オプティマイザの定義
    #optimizer = torch.optim.SGD(model.parameters(), lr=1e-3)
    device = torch.device('cuda')# デバイスの指定
    
    # モデルの学習
    dataloader_train = load_Dataloader("train",64)
    dataloader_valid = load_Dataloader("valid", 64)
    dataloader_test = load_Dataloader("test", 64)
    log = train_model(dataloader_train, dataloader_valid,model, criterion, optimizer, 100,device=device)
    
    loss_train, acc_train = calculate_loss_and_accuracy(model, criterion, dataloader_train, device)
    loss_test, acc_test = calculate_loss_and_accuracy(model, criterion, dataloader_test, device)
    print(f"学習データでの正解率:{acc_train}")
    print(f"評価データでの正解率:{acc_test}")
# Out:
# epoch: 1, loss_train: 0.5758, accuracy_train: 0.8032, loss_valid: 0.5701, accuracy_valid: 0.8066, 0.4184sec
# epoch: 2, loss_train: 0.4805, accuracy_train: 0.8233, loss_valid: 0.4805, accuracy_valid: 0.8216, 0.4030sec
# epoch: 3, loss_train: 0.4382, accuracy_train: 0.8324, loss_valid: 0.4477, accuracy_valid: 0.8291, 0.4289sec
# epoch: 4, loss_train: 0.4122, accuracy_train: 0.8399, loss_valid: 0.4318, accuracy_valid: 0.8313, 0.4089sec
# epoch: 5, loss_train: 0.3927, accuracy_train: 0.8483, loss_valid: 0.4221, accuracy_valid: 0.8388, 0.3951sec
# epoch: 6, loss_train: 0.3167, accuracy_train: 0.8934, loss_valid: 0.3504, accuracy_valid: 0.8831, 0.3858sec
# epoch: 7, loss_train: 0.2967, accuracy_train: 0.9013, loss_valid: 0.3377, accuracy_valid: 0.8906, 0.3979sec
# epoch: 8, loss_train: 0.2820, accuracy_train: 0.9050, loss_valid: 0.3360, accuracy_valid: 0.8921, 0.3930sec
# epoch: 9, loss_train: 0.2677, accuracy_train: 0.9132, loss_valid: 0.3269, accuracy_valid: 0.8898, 0.3860sec
# epoch: 10, loss_train: 0.2569, accuracy_train: 0.9134, loss_valid: 0.3242, accuracy_valid: 0.8921, 0.3929sec
# epoch: 11, loss_train: 0.2459, accuracy_train: 0.9199, loss_valid: 0.3217, accuracy_valid: 0.8921, 0.3969sec
# epoch: 12, loss_train: 0.2356, accuracy_train: 0.9220, loss_valid: 0.3211, accuracy_valid: 0.8898, 0.3880sec
# epoch: 13, loss_train: 0.2257, accuracy_train: 0.9286, loss_valid: 0.3177, accuracy_valid: 0.8928, 0.4149sec
# epoch: 14, loss_train: 0.2162, accuracy_train: 0.9322, loss_valid: 0.3159, accuracy_valid: 0.8936, 0.4024sec
# epoch: 15, loss_train: 0.2067, accuracy_train: 0.9362, loss_valid: 0.3158, accuracy_valid: 0.8981, 0.3999sec
# epoch: 16, loss_train: 0.1995, accuracy_train: 0.9382, loss_valid: 0.3132, accuracy_valid: 0.8988, 0.3905sec
# epoch: 17, loss_train: 0.1959, accuracy_train: 0.9383, loss_valid: 0.3221, accuracy_valid: 0.8943, 0.3889sec
# epoch: 18, loss_train: 0.1846, accuracy_train: 0.9443, loss_valid: 0.3131, accuracy_valid: 0.9010, 0.4328sec
# epoch: 19, loss_train: 0.1786, accuracy_train: 0.9439, loss_valid: 0.3209, accuracy_valid: 0.8958, 0.3972sec
# epoch: 20, loss_train: 0.1716, accuracy_train: 0.9494, loss_valid: 0.3158, accuracy_valid: 0.8996, 0.3900sec
# epoch: 21, loss_train: 0.1661, accuracy_train: 0.9506, loss_valid: 0.3128, accuracy_valid: 0.9018, 0.4040sec
# epoch: 22, loss_train: 0.1609, accuracy_train: 0.9539, loss_valid: 0.3137, accuracy_valid: 0.8988, 0.4328sec
# epoch: 23, loss_train: 0.1525, accuracy_train: 0.9561, loss_valid: 0.3120, accuracy_valid: 0.9025, 0.4214sec
# epoch: 24, loss_train: 0.1490, accuracy_train: 0.9568, loss_valid: 0.3157, accuracy_valid: 0.9003, 0.4089sec
# epoch: 25, loss_train: 0.1452, accuracy_train: 0.9569, loss_valid: 0.3187, accuracy_valid: 0.9025, 0.4249sec
# epoch: 26, loss_train: 0.1375, accuracy_train: 0.9599, loss_valid: 0.3229, accuracy_valid: 0.9003, 0.4124sec
# epoch: 27, loss_train: 0.1353, accuracy_train: 0.9601, loss_valid: 0.3230, accuracy_valid: 0.8973, 0.3989sec
# epoch: 28, loss_train: 0.1289, accuracy_train: 0.9630, loss_valid: 0.3149, accuracy_valid: 0.9040, 0.3979sec
# epoch: 29, loss_train: 0.1237, accuracy_train: 0.9652, loss_valid: 0.3162, accuracy_valid: 0.9033, 0.4294sec
# epoch: 30, loss_train: 0.1193, accuracy_train: 0.9667, loss_valid: 0.3243, accuracy_valid: 0.8996, 0.3913sec
# epoch: 31, loss_train: 0.1149, accuracy_train: 0.9681, loss_valid: 0.3233, accuracy_valid: 0.9040, 0.3929sec
# epoch: 32, loss_train: 0.1099, accuracy_train: 0.9700, loss_valid: 0.3257, accuracy_valid: 0.9033, 0.3900sec
# epoch: 33, loss_train: 0.1066, accuracy_train: 0.9707, loss_valid: 0.3242, accuracy_valid: 0.9070, 0.3870sec
# epoch: 34, loss_train: 0.1030, accuracy_train: 0.9715, loss_valid: 0.3245, accuracy_valid: 0.9010, 0.4099sec
# epoch: 35, loss_train: 0.0988, accuracy_train: 0.9732, loss_valid: 0.3280, accuracy_valid: 0.9033, 0.4079sec
# epoch: 36, loss_train: 0.0960, accuracy_train: 0.9750, loss_valid: 0.3235, accuracy_valid: 0.8988, 0.4089sec
# epoch: 37, loss_train: 0.0924, accuracy_train: 0.9762, loss_valid: 0.3298, accuracy_valid: 0.9018, 0.4171sec
# epoch: 38, loss_train: 0.0915, accuracy_train: 0.9762, loss_valid: 0.3301, accuracy_valid: 0.8973, 0.4089sec
# epoch: 39, loss_train: 0.0855, accuracy_train: 0.9786, loss_valid: 0.3372, accuracy_valid: 0.9055, 0.4022sec
# epoch: 40, loss_train: 0.0839, accuracy_train: 0.9793, loss_valid: 0.3333, accuracy_valid: 0.9040, 0.4219sec
# epoch: 41, loss_train: 0.0814, accuracy_train: 0.9807, loss_valid: 0.3325, accuracy_valid: 0.9018, 0.4099sec
# epoch: 42, loss_train: 0.0793, accuracy_train: 0.9796, loss_valid: 0.3425, accuracy_valid: 0.9025, 0.4271sec
# epoch: 43, loss_train: 0.0761, accuracy_train: 0.9813, loss_valid: 0.3404, accuracy_valid: 0.9040, 0.4079sec
# epoch: 44, loss_train: 0.0749, accuracy_train: 0.9819, loss_valid: 0.3414, accuracy_valid: 0.8988, 0.4089sec
# epoch: 45, loss_train: 0.0735, accuracy_train: 0.9814, loss_valid: 0.3444, accuracy_valid: 0.8996, 0.4040sec
# epoch: 46, loss_train: 0.0688, accuracy_train: 0.9837, loss_valid: 0.3442, accuracy_valid: 0.9018, 0.3910sec
# epoch: 47, loss_train: 0.0695, accuracy_train: 0.9827, loss_valid: 0.3505, accuracy_valid: 0.9018, 0.3870sec
# epoch: 48, loss_train: 0.0668, accuracy_train: 0.9842, loss_valid: 0.3532, accuracy_valid: 0.9025, 0.3984sec
# epoch: 49, loss_train: 0.0670, accuracy_train: 0.9831, loss_valid: 0.3507, accuracy_valid: 0.9010, 0.4039sec
# epoch: 50, loss_train: 0.0621, accuracy_train: 0.9858, loss_valid: 0.3529, accuracy_valid: 0.9070, 0.4043sec
# epoch: 51, loss_train: 0.0615, accuracy_train: 0.9852, loss_valid: 0.3535, accuracy_valid: 0.9033, 0.4265sec
# epoch: 52, loss_train: 0.0615, accuracy_train: 0.9858, loss_valid: 0.3534, accuracy_valid: 0.9033, 0.4099sec
# epoch: 53, loss_train: 0.0607, accuracy_train: 0.9853, loss_valid: 0.3574, accuracy_valid: 0.9025, 0.4073sec
# epoch: 54, loss_train: 0.0584, accuracy_train: 0.9858, loss_valid: 0.3618, accuracy_valid: 0.9003, 0.4029sec
# epoch: 55, loss_train: 0.0562, accuracy_train: 0.9871, loss_valid: 0.3525, accuracy_valid: 0.9018, 0.4029sec
# epoch: 56, loss_train: 0.0572, accuracy_train: 0.9864, loss_valid: 0.3680, accuracy_valid: 0.9010, 0.4238sec
# epoch: 57, loss_train: 0.0545, accuracy_train: 0.9867, loss_valid: 0.3670, accuracy_valid: 0.8996, 0.4166sec
# epoch: 58, loss_train: 0.0529, accuracy_train: 0.9872, loss_valid: 0.3594, accuracy_valid: 0.9010, 0.4159sec
# epoch: 59, loss_train: 0.0521, accuracy_train: 0.9876, loss_valid: 0.3636, accuracy_valid: 0.9003, 0.4151sec
# epoch: 60, loss_train: 0.0505, accuracy_train: 0.9882, loss_valid: 0.3628, accuracy_valid: 0.9048, 0.4170sec
# epoch: 61, loss_train: 0.0496, accuracy_train: 0.9881, loss_valid: 0.3655, accuracy_valid: 0.9033, 0.4089sec
# epoch: 62, loss_train: 0.0500, accuracy_train: 0.9883, loss_valid: 0.3731, accuracy_valid: 0.9003, 0.4019sec
# epoch: 63, loss_train: 0.0499, accuracy_train: 0.9876, loss_valid: 0.3723, accuracy_valid: 0.8988, 0.4079sec
# epoch: 64, loss_train: 0.0481, accuracy_train: 0.9885, loss_valid: 0.3629, accuracy_valid: 0.9010, 0.4094sec
# epoch: 65, loss_train: 0.0467, accuracy_train: 0.9886, loss_valid: 0.3697, accuracy_valid: 0.9010, 0.4140sec
# epoch: 66, loss_train: 0.0464, accuracy_train: 0.9886, loss_valid: 0.3714, accuracy_valid: 0.9018, 0.3991sec
# epoch: 67, loss_train: 0.0456, accuracy_train: 0.9888, loss_valid: 0.3673, accuracy_valid: 0.8996, 0.4021sec
# epoch: 68, loss_train: 0.0461, accuracy_train: 0.9888, loss_valid: 0.3670, accuracy_valid: 0.9040, 0.4129sec
# epoch: 69, loss_train: 0.0454, accuracy_train: 0.9893, loss_valid: 0.3694, accuracy_valid: 0.8996, 0.3959sec
# epoch: 70, loss_train: 0.0441, accuracy_train: 0.9893, loss_valid: 0.3792, accuracy_valid: 0.8996, 0.3840sec
# epoch: 71, loss_train: 0.0441, accuracy_train: 0.9895, loss_valid: 0.3836, accuracy_valid: 0.8996, 0.4046sec
# epoch: 72, loss_train: 0.0435, accuracy_train: 0.9894, loss_valid: 0.3780, accuracy_valid: 0.8988, 0.4103sec
# epoch: 73, loss_train: 0.0431, accuracy_train: 0.9900, loss_valid: 0.3774, accuracy_valid: 0.9025, 0.4209sec
# epoch: 74, loss_train: 0.0424, accuracy_train: 0.9898, loss_valid: 0.3798, accuracy_valid: 0.8981, 0.4181sec
# epoch: 75, loss_train: 0.0427, accuracy_train: 0.9900, loss_valid: 0.3716, accuracy_valid: 0.9003, 0.4019sec
# epoch: 76, loss_train: 0.0415, accuracy_train: 0.9901, loss_valid: 0.3810, accuracy_valid: 0.9033, 0.3870sec
# epoch: 77, loss_train: 0.0411, accuracy_train: 0.9900, loss_valid: 0.3823, accuracy_valid: 0.9003, 0.3994sec
# epoch: 78, loss_train: 0.0411, accuracy_train: 0.9905, loss_valid: 0.3755, accuracy_valid: 0.9003, 0.4049sec
# epoch: 79, loss_train: 0.0414, accuracy_train: 0.9900, loss_valid: 0.3817, accuracy_valid: 0.9010, 0.3939sec
# epoch: 80, loss_train: 0.0411, accuracy_train: 0.9900, loss_valid: 0.3787, accuracy_valid: 0.9003, 0.3920sec
# epoch: 81, loss_train: 0.0406, accuracy_train: 0.9903, loss_valid: 0.3755, accuracy_valid: 0.9040, 0.4099sec
# epoch: 82, loss_train: 0.0402, accuracy_train: 0.9903, loss_valid: 0.3760, accuracy_valid: 0.9048, 0.4266sec
# epoch: 83, loss_train: 0.0399, accuracy_train: 0.9903, loss_valid: 0.3798, accuracy_valid: 0.9018, 0.3893sec
# epoch: 84, loss_train: 0.0416, accuracy_train: 0.9901, loss_valid: 0.3834, accuracy_valid: 0.8996, 0.3990sec
# epoch: 85, loss_train: 0.0390, accuracy_train: 0.9906, loss_valid: 0.3817, accuracy_valid: 0.9010, 0.4269sec
# epoch: 86, loss_train: 0.0396, accuracy_train: 0.9906, loss_valid: 0.3775, accuracy_valid: 0.9010, 0.4069sec
# epoch: 87, loss_train: 0.0391, accuracy_train: 0.9907, loss_valid: 0.3825, accuracy_valid: 0.9010, 0.3864sec
# epoch: 88, loss_train: 0.0406, accuracy_train: 0.9902, loss_valid: 0.3809, accuracy_valid: 0.9018, 0.4109sec
# epoch: 89, loss_train: 0.0390, accuracy_train: 0.9906, loss_valid: 0.3828, accuracy_valid: 0.9018, 0.4056sec
# epoch: 90, loss_train: 0.0395, accuracy_train: 0.9904, loss_valid: 0.3843, accuracy_valid: 0.8996, 0.3815sec
# epoch: 91, loss_train: 0.0386, accuracy_train: 0.9910, loss_valid: 0.3788, accuracy_valid: 0.9040, 0.3979sec
# epoch: 92, loss_train: 0.0388, accuracy_train: 0.9905, loss_valid: 0.3779, accuracy_valid: 0.9025, 0.4019sec
# epoch: 93, loss_train: 0.0383, accuracy_train: 0.9905, loss_valid: 0.3818, accuracy_valid: 0.9010, 0.4299sec
# epoch: 94, loss_train: 0.0400, accuracy_train: 0.9907, loss_valid: 0.3862, accuracy_valid: 0.8966, 0.4046sec
# epoch: 95, loss_train: 0.0386, accuracy_train: 0.9912, loss_valid: 0.3779, accuracy_valid: 0.9018, 0.3905sec
# epoch: 96, loss_train: 0.0393, accuracy_train: 0.9908, loss_valid: 0.3727, accuracy_valid: 0.9010, 0.4009sec
# epoch: 97, loss_train: 0.0381, accuracy_train: 0.9903, loss_valid: 0.3837, accuracy_valid: 0.9025, 0.4281sec
# epoch: 98, loss_train: 0.0391, accuracy_train: 0.9906, loss_valid: 0.3825, accuracy_valid: 0.9010, 0.4046sec
# epoch: 99, loss_train: 0.0392, accuracy_train: 0.9907, loss_valid: 0.3856, accuracy_valid: 0.8996, 0.3890sec
# epoch: 100, loss_train: 0.0384, accuracy_train: 0.9907, loss_valid: 0.3774, accuracy_valid: 0.9010, 0.3929sec
# 学習データでの正解率:0.990723388305847
# 評価データでの正解率:0.9070464767616192
