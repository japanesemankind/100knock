# %%
from torch.utils.data import Dataset
from torch import nn
import torch
from torch.utils.data import DataLoader
#from q71 import SLPNet
from q73 import NewsDataset
from q74 import load_Dataloader
from q78 import calculate_loss_and_accuracy
import time
from torch.nn import functional as F

# class SLPNet(nn.Module):
#     def __init__(self, input_size, output_size,mid_size):        
#         super().__init__()
#         self.fc = nn.Linear(input_size,mid_size)        
#         self.fc2= nn.Linear(mid_size, mid_size)
#         self.fc3=nn.Linear(mid_size, output_size)
#         #正則化とドロップアウトを追加
#         self.dropout = nn.Dropout(0.5)
#         self.bn = nn.BatchNorm1d(mid_size)
# #        nn.init.normal_(self.fc.weight, 0.0, 1.0)  # 正規乱数で重みを初期化
        
#     def forward(self, x):
#         x = F.relu(self.fc(x))
#         x = F.relu(self.fc2(x))
#         x = self.dropout(x)
#         x = F.relu(self.bn(x))
#         x = self.dropout(x)
#         x = F.relu(self.fc3(x))        
# #        x = self.relu(x)
# #        x = self.dropout(x)
        
#         return x
    
class MLPNet(nn.Module):
    def __init__(self, input_size, mid_size, output_size, mid_layers):
        super().__init__()
        self.mid_layers = mid_layers
        self.fc = nn.Linear(input_size, mid_size)
        self.fc_mid = nn.Linear(mid_size, mid_size)
        self.fc_out = nn.Linear(mid_size, output_size) 
        self.bn = nn.BatchNorm1d(mid_size)
        
    def forward(self, x):
        x = F.relu(self.fc(x))
        
        for _ in range(self.mid_layers):
            x = F.relu(self.bn(self.fc_mid(x)))
            x = F.relu(self.fc_out(x))
            
        return x    

def train_model(dataloader_train, dataloader_valid,model, criterion, optimizer, num_epochs, device=None):
    # GPUに送る
    model.to(device)

    
    # 学習
    log_train = []
    log_valid = []
    
    scheduler =torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, num_epochs, eta_min=1e-5)
    #scheduler = torch.optim.lr_scheduler.StepLR(optimizer,num_epochs/5,0.5)
    for epoch in range(num_epochs):
        # 開始時刻の記録
        s_time = time.time()
        
        # 訓練モードに設定 
        model.train()
        
        for inputs, labels in dataloader_train:
            # 勾配をゼロで初期化
            optimizer.zero_grad()
            # 順伝播 + 誤差逆伝播 + 重み更新
            inputs = inputs.to(device)
            labels = labels.to(device)
            outputs = model.forward(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            
        # 損失と正解率の算出
        loss_train, acc_train = calculate_loss_and_accuracy(model, criterion, dataloader_train, device)
        loss_valid, acc_valid = calculate_loss_and_accuracy(model, criterion, dataloader_valid, device)
        log_train.append([loss_train, acc_train])
        log_valid.append([loss_valid, acc_valid])
            
        # チェックポイントの保存
#        torch.save({'epoch': epoch, 'model_state_dict': model.state_dict(), 'optimizer_state_dict': optimizer.state_dict()}, f'checkpoint{epoch + 1}.pt')
            
        # 終了時刻の記録
        e_time = time.time()
        
        # ログを出力
        print(f'epoch: {epoch + 1}, loss_train: {loss_train:.4f}, accuracy_train: {acc_train:.4f}, loss_valid: {loss_valid:.4f}, accuracy_valid: {acc_valid:.4f}, {(e_time - s_time):.4f}sec') 
        
        if epoch > 2 and log_valid[epoch - 3][0] <= log_valid[epoch - 2][0] <= log_valid[epoch - 1][0] <= log_valid[epoch][0]:
            break
        scheduler.step()
    return {'train': log_train, 'valid': log_valid}

if __name__=="__main__":

    
#    model = SLPNet(300, 4,200)# モデルの定義    
    model = MLPNet(300, 200, 4, 1)
    criterion = nn.CrossEntropyLoss()# 損失関数の定義
    #optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)# オプティマイザの定義
    optimizer = torch.optim.SGD(model.parameters(), lr=1e-3)
    device = torch.device('cuda')# デバイスの指定
    
    # モデルの学習
    dataloader_train = load_Dataloader("train",64)
#    dataloader_valid = load_Dataloader("valid", 64)
#    dataloader_test = load_Dataloader("test", 64)

#     X_train=torch.load("X_train2.pt")
#     Y_train=torch.load("Y_train2.pt")
#     dataset_train=NewsDataset(X_train,Y_train)
#     dataloader_train=DataLoader(dataset_train, 64, shuffle=True)
    
    X_valid=torch.load("X_valid2.pt")
    Y_valid=torch.load("Y_valid2.pt")
    dataset_valid=NewsDataset(X_valid,Y_valid)
    dataloader_valid=DataLoader(dataset_valid, len(dataset_valid), shuffle=False)
    
    X_test=torch.load("X_test2.pt")
    Y_test=torch.load("Y_test2.pt")
    dataset_test=NewsDataset(X_test,Y_test)
    dataloader_test=DataLoader(dataset_test,len(dataset_test), shuffle=False)
    
    
    log = train_model(dataloader_train, dataloader_valid,model, criterion, optimizer, 1000,device=device)
    
    loss_train, acc_train = calculate_loss_and_accuracy(model, criterion, dataloader_train, device)
    loss_test, acc_test = calculate_loss_and_accuracy(model, criterion, dataloader_test, device)
    print(f"学習データでの正解率:{acc_train}")
    print(f"評価データでの正解率:{acc_test}")
# Out:
# epoch: 1, loss_train: 0.9033, accuracy_train: 0.7393, loss_valid: 0.9031, accuracy_valid: 0.7369, 0.3723sec
# epoch: 2, loss_train: 0.7501, accuracy_train: 0.7581, loss_valid: 0.7507, accuracy_valid: 0.7571, 0.3680sec
# epoch: 3, loss_train: 0.6833, accuracy_train: 0.7688, loss_valid: 0.6839, accuracy_valid: 0.7691, 0.3858sec
# epoch: 4, loss_train: 0.6409, accuracy_train: 0.7774, loss_valid: 0.6417, accuracy_valid: 0.7796, 0.3852sec
# epoch: 5, loss_train: 0.6045, accuracy_train: 0.7900, loss_valid: 0.6054, accuracy_valid: 0.7916, 0.3810sec
# epoch: 6, loss_train: 0.5722, accuracy_train: 0.8027, loss_valid: 0.5732, accuracy_valid: 0.8051, 0.3695sec
# epoch: 7, loss_train: 0.5436, accuracy_train: 0.8145, loss_valid: 0.5456, accuracy_valid: 0.8133, 0.3943sec
# epoch: 8, loss_train: 0.5181, accuracy_train: 0.8264, loss_valid: 0.5207, accuracy_valid: 0.8276, 0.3780sec
# epoch: 9, loss_train: 0.4961, accuracy_train: 0.8384, loss_valid: 0.5007, accuracy_valid: 0.8366, 0.3638sec
# epoch: 10, loss_train: 0.4779, accuracy_train: 0.8414, loss_valid: 0.4838, accuracy_valid: 0.8388, 0.3584sec
# epoch: 11, loss_train: 0.4614, accuracy_train: 0.8504, loss_valid: 0.4684, accuracy_valid: 0.8508, 0.3776sec
# epoch: 12, loss_train: 0.4477, accuracy_train: 0.8561, loss_valid: 0.4569, accuracy_valid: 0.8583, 0.3560sec
# epoch: 13, loss_train: 0.4355, accuracy_train: 0.8605, loss_valid: 0.4462, accuracy_valid: 0.8546, 0.3670sec
# epoch: 14, loss_train: 0.4237, accuracy_train: 0.8619, loss_valid: 0.4358, accuracy_valid: 0.8546, 0.3708sec
# epoch: 15, loss_train: 0.4172, accuracy_train: 0.8674, loss_valid: 0.4300, accuracy_valid: 0.8651, 0.3581sec
# epoch: 16, loss_train: 0.4069, accuracy_train: 0.8710, loss_valid: 0.4216, accuracy_valid: 0.8658, 0.3910sec
# epoch: 17, loss_train: 0.3979, accuracy_train: 0.8724, loss_valid: 0.4140, accuracy_valid: 0.8651, 0.3674sec
# epoch: 18, loss_train: 0.3888, accuracy_train: 0.8760, loss_valid: 0.4066, accuracy_valid: 0.8711, 0.3740sec
# epoch: 19, loss_train: 0.3817, accuracy_train: 0.8753, loss_valid: 0.4018, accuracy_valid: 0.8688, 0.3560sec
# epoch: 20, loss_train: 0.3732, accuracy_train: 0.8772, loss_valid: 0.3951, accuracy_valid: 0.8703, 0.3556sec
# epoch: 21, loss_train: 0.3680, accuracy_train: 0.8812, loss_valid: 0.3908, accuracy_valid: 0.8726, 0.3560sec
# epoch: 22, loss_train: 0.3631, accuracy_train: 0.8813, loss_valid: 0.3872, accuracy_valid: 0.8733, 0.3810sec
# epoch: 23, loss_train: 0.3571, accuracy_train: 0.8831, loss_valid: 0.3829, accuracy_valid: 0.8756, 0.3806sec
# epoch: 24, loss_train: 0.3526, accuracy_train: 0.8832, loss_valid: 0.3791, accuracy_valid: 0.8756, 0.3763sec
# epoch: 25, loss_train: 0.3482, accuracy_train: 0.8863, loss_valid: 0.3763, accuracy_valid: 0.8763, 0.3985sec
# epoch: 26, loss_train: 0.3429, accuracy_train: 0.8871, loss_valid: 0.3726, accuracy_valid: 0.8756, 0.3949sec
# epoch: 27, loss_train: 0.3385, accuracy_train: 0.8882, loss_valid: 0.3693, accuracy_valid: 0.8748, 0.3880sec
# epoch: 28, loss_train: 0.3333, accuracy_train: 0.8891, loss_valid: 0.3663, accuracy_valid: 0.8756, 0.3824sec
# epoch: 29, loss_train: 0.3305, accuracy_train: 0.8896, loss_valid: 0.3647, accuracy_valid: 0.8756, 0.3680sec
# epoch: 30, loss_train: 0.3270, accuracy_train: 0.8911, loss_valid: 0.3623, accuracy_valid: 0.8748, 0.4015sec
# epoch: 31, loss_train: 0.3236, accuracy_train: 0.8919, loss_valid: 0.3604, accuracy_valid: 0.8786, 0.3658sec
# epoch: 32, loss_train: 0.3209, accuracy_train: 0.8931, loss_valid: 0.3583, accuracy_valid: 0.8786, 0.3614sec
# epoch: 33, loss_train: 0.3177, accuracy_train: 0.8949, loss_valid: 0.3567, accuracy_valid: 0.8786, 0.3899sec
# epoch: 34, loss_train: 0.3144, accuracy_train: 0.8959, loss_valid: 0.3555, accuracy_valid: 0.8823, 0.4014sec
# epoch: 35, loss_train: 0.3104, accuracy_train: 0.8967, loss_valid: 0.3537, accuracy_valid: 0.8801, 0.3694sec
# epoch: 36, loss_train: 0.3082, accuracy_train: 0.8981, loss_valid: 0.3519, accuracy_valid: 0.8816, 0.3631sec
# epoch: 37, loss_train: 0.3052, accuracy_train: 0.8977, loss_valid: 0.3513, accuracy_valid: 0.8816, 0.4182sec
# epoch: 38, loss_train: 0.3039, accuracy_train: 0.8978, loss_valid: 0.3496, accuracy_valid: 0.8853, 0.3760sec
# epoch: 39, loss_train: 0.2996, accuracy_train: 0.9005, loss_valid: 0.3474, accuracy_valid: 0.8816, 0.3943sec
# epoch: 40, loss_train: 0.2969, accuracy_train: 0.9011, loss_valid: 0.3474, accuracy_valid: 0.8793, 0.3880sec
# epoch: 41, loss_train: 0.2936, accuracy_train: 0.9019, loss_valid: 0.3452, accuracy_valid: 0.8823, 0.3979sec
# epoch: 42, loss_train: 0.2909, accuracy_train: 0.9020, loss_valid: 0.3443, accuracy_valid: 0.8786, 0.3880sec
# epoch: 43, loss_train: 0.2891, accuracy_train: 0.9039, loss_valid: 0.3422, accuracy_valid: 0.8823, 0.3967sec
# epoch: 44, loss_train: 0.2866, accuracy_train: 0.9053, loss_valid: 0.3427, accuracy_valid: 0.8786, 0.3640sec
# epoch: 45, loss_train: 0.2858, accuracy_train: 0.9054, loss_valid: 0.3409, accuracy_valid: 0.8816, 0.3811sec
# epoch: 46, loss_train: 0.2824, accuracy_train: 0.9059, loss_valid: 0.3397, accuracy_valid: 0.8823, 0.3810sec
# epoch: 47, loss_train: 0.2795, accuracy_train: 0.9056, loss_valid: 0.3403, accuracy_valid: 0.8816, 0.3870sec
# epoch: 48, loss_train: 0.2778, accuracy_train: 0.9076, loss_valid: 0.3383, accuracy_valid: 0.8793, 0.3880sec
# epoch: 49, loss_train: 0.2756, accuracy_train: 0.9066, loss_valid: 0.3384, accuracy_valid: 0.8801, 0.3626sec
# epoch: 50, loss_train: 0.2745, accuracy_train: 0.9067, loss_valid: 0.3389, accuracy_valid: 0.8801, 0.3820sec
# epoch: 51, loss_train: 0.2715, accuracy_train: 0.9088, loss_valid: 0.3363, accuracy_valid: 0.8801, 0.3790sec
# epoch: 52, loss_train: 0.2704, accuracy_train: 0.9085, loss_valid: 0.3359, accuracy_valid: 0.8808, 0.3832sec
# epoch: 53, loss_train: 0.2689, accuracy_train: 0.9087, loss_valid: 0.3351, accuracy_valid: 0.8816, 0.4077sec
# epoch: 54, loss_train: 0.2672, accuracy_train: 0.9105, loss_valid: 0.3340, accuracy_valid: 0.8816, 0.4044sec
# epoch: 55, loss_train: 0.2656, accuracy_train: 0.9123, loss_valid: 0.3326, accuracy_valid: 0.8816, 0.3636sec
# epoch: 56, loss_train: 0.2623, accuracy_train: 0.9132, loss_valid: 0.3323, accuracy_valid: 0.8823, 0.3940sec
# epoch: 57, loss_train: 0.2605, accuracy_train: 0.9131, loss_valid: 0.3324, accuracy_valid: 0.8823, 0.3720sec
# epoch: 58, loss_train: 0.2598, accuracy_train: 0.9132, loss_valid: 0.3307, accuracy_valid: 0.8861, 0.3680sec
# epoch: 59, loss_train: 0.2574, accuracy_train: 0.9149, loss_valid: 0.3308, accuracy_valid: 0.8861, 0.3740sec
# epoch: 60, loss_train: 0.2550, accuracy_train: 0.9147, loss_valid: 0.3301, accuracy_valid: 0.8876, 0.3551sec
# epoch: 61, loss_train: 0.2534, accuracy_train: 0.9156, loss_valid: 0.3302, accuracy_valid: 0.8876, 0.3830sec
# epoch: 62, loss_train: 0.2517, accuracy_train: 0.9159, loss_valid: 0.3299, accuracy_valid: 0.8831, 0.3600sec
# epoch: 63, loss_train: 0.2498, accuracy_train: 0.9161, loss_valid: 0.3284, accuracy_valid: 0.8861, 0.3747sec
# epoch: 64, loss_train: 0.2489, accuracy_train: 0.9179, loss_valid: 0.3283, accuracy_valid: 0.8868, 0.3717sec
# epoch: 65, loss_train: 0.2466, accuracy_train: 0.9174, loss_valid: 0.3273, accuracy_valid: 0.8876, 0.3679sec
# epoch: 66, loss_train: 0.2452, accuracy_train: 0.9187, loss_valid: 0.3272, accuracy_valid: 0.8891, 0.3740sec
# epoch: 67, loss_train: 0.2450, accuracy_train: 0.9194, loss_valid: 0.3287, accuracy_valid: 0.8906, 0.3610sec
# epoch: 68, loss_train: 0.2417, accuracy_train: 0.9189, loss_valid: 0.3286, accuracy_valid: 0.8868, 0.3760sec
# epoch: 69, loss_train: 0.2404, accuracy_train: 0.9206, loss_valid: 0.3273, accuracy_valid: 0.8913, 0.3769sec
# epoch: 70, loss_train: 0.2389, accuracy_train: 0.9207, loss_valid: 0.3273, accuracy_valid: 0.8913, 0.3737sec
# epoch: 71, loss_train: 0.2377, accuracy_train: 0.9217, loss_valid: 0.3271, accuracy_valid: 0.8928, 0.3725sec
# epoch: 72, loss_train: 0.2353, accuracy_train: 0.9219, loss_valid: 0.3255, accuracy_valid: 0.8906, 0.3710sec
# epoch: 73, loss_train: 0.2348, accuracy_train: 0.9230, loss_valid: 0.3281, accuracy_valid: 0.8921, 0.3710sec
# epoch: 74, loss_train: 0.2321, accuracy_train: 0.9235, loss_valid: 0.3256, accuracy_valid: 0.8913, 0.3700sec
# epoch: 75, loss_train: 0.2317, accuracy_train: 0.9234, loss_valid: 0.3237, accuracy_valid: 0.8906, 0.3939sec
# epoch: 76, loss_train: 0.2296, accuracy_train: 0.9246, loss_valid: 0.3243, accuracy_valid: 0.8936, 0.3648sec
# epoch: 77, loss_train: 0.2320, accuracy_train: 0.9230, loss_valid: 0.3246, accuracy_valid: 0.8898, 0.3700sec
# epoch: 78, loss_train: 0.2269, accuracy_train: 0.9261, loss_valid: 0.3244, accuracy_valid: 0.8928, 0.3700sec
# epoch: 79, loss_train: 0.2264, accuracy_train: 0.9264, loss_valid: 0.3257, accuracy_valid: 0.8943, 0.3723sec
# epoch: 80, loss_train: 0.2237, accuracy_train: 0.9256, loss_valid: 0.3230, accuracy_valid: 0.8921, 0.3700sec
# epoch: 81, loss_train: 0.2226, accuracy_train: 0.9264, loss_valid: 0.3237, accuracy_valid: 0.8943, 0.3750sec
# epoch: 82, loss_train: 0.2211, accuracy_train: 0.9287, loss_valid: 0.3223, accuracy_valid: 0.8958, 0.3720sec
# epoch: 83, loss_train: 0.2199, accuracy_train: 0.9285, loss_valid: 0.3216, accuracy_valid: 0.8958, 0.3718sec
# epoch: 84, loss_train: 0.2181, accuracy_train: 0.9293, loss_valid: 0.3234, accuracy_valid: 0.8943, 0.3798sec
# epoch: 85, loss_train: 0.2174, accuracy_train: 0.9291, loss_valid: 0.3227, accuracy_valid: 0.8928, 0.3954sec
# epoch: 86, loss_train: 0.2152, accuracy_train: 0.9306, loss_valid: 0.3212, accuracy_valid: 0.8958, 0.3583sec
# epoch: 87, loss_train: 0.2162, accuracy_train: 0.9308, loss_valid: 0.3244, accuracy_valid: 0.8898, 0.3886sec
# epoch: 88, loss_train: 0.2138, accuracy_train: 0.9315, loss_valid: 0.3201, accuracy_valid: 0.8966, 0.3592sec
# epoch: 89, loss_train: 0.2113, accuracy_train: 0.9324, loss_valid: 0.3204, accuracy_valid: 0.8943, 0.3720sec
# epoch: 90, loss_train: 0.2144, accuracy_train: 0.9299, loss_valid: 0.3213, accuracy_valid: 0.8943, 0.3879sec
# epoch: 91, loss_train: 0.2094, accuracy_train: 0.9325, loss_valid: 0.3198, accuracy_valid: 0.8936, 0.3730sec
# epoch: 92, loss_train: 0.2086, accuracy_train: 0.9333, loss_valid: 0.3197, accuracy_valid: 0.8966, 0.3833sec
# epoch: 93, loss_train: 0.2056, accuracy_train: 0.9347, loss_valid: 0.3202, accuracy_valid: 0.8966, 0.3752sec
# epoch: 94, loss_train: 0.2050, accuracy_train: 0.9343, loss_valid: 0.3199, accuracy_valid: 0.8966, 0.3900sec
# epoch: 95, loss_train: 0.2041, accuracy_train: 0.9353, loss_valid: 0.3197, accuracy_valid: 0.8943, 0.3690sec
# epoch: 96, loss_train: 0.2031, accuracy_train: 0.9372, loss_valid: 0.3187, accuracy_valid: 0.8981, 0.3705sec
# epoch: 97, loss_train: 0.2026, accuracy_train: 0.9353, loss_valid: 0.3191, accuracy_valid: 0.8981, 0.3787sec
# epoch: 98, loss_train: 0.1998, accuracy_train: 0.9372, loss_valid: 0.3200, accuracy_valid: 0.8958, 0.3833sec
# epoch: 99, loss_train: 0.1980, accuracy_train: 0.9371, loss_valid: 0.3189, accuracy_valid: 0.8966, 0.3742sec
# epoch: 100, loss_train: 0.1988, accuracy_train: 0.9369, loss_valid: 0.3190, accuracy_valid: 0.8981, 0.3700sec
# epoch: 101, loss_train: 0.1961, accuracy_train: 0.9385, loss_valid: 0.3194, accuracy_valid: 0.8958, 0.3650sec
# epoch: 102, loss_train: 0.1942, accuracy_train: 0.9389, loss_valid: 0.3176, accuracy_valid: 0.9003, 0.3750sec
# epoch: 103, loss_train: 0.1933, accuracy_train: 0.9387, loss_valid: 0.3174, accuracy_valid: 0.8996, 0.3694sec
# epoch: 104, loss_train: 0.1926, accuracy_train: 0.9407, loss_valid: 0.3209, accuracy_valid: 0.8928, 0.3690sec
# epoch: 105, loss_train: 0.1905, accuracy_train: 0.9409, loss_valid: 0.3180, accuracy_valid: 0.8988, 0.3740sec
# epoch: 106, loss_train: 0.1901, accuracy_train: 0.9412, loss_valid: 0.3185, accuracy_valid: 0.8936, 0.3871sec
# epoch: 107, loss_train: 0.1891, accuracy_train: 0.9418, loss_valid: 0.3198, accuracy_valid: 0.8943, 0.3601sec
# epoch: 108, loss_train: 0.1876, accuracy_train: 0.9422, loss_valid: 0.3175, accuracy_valid: 0.8996, 0.3750sec
# epoch: 109, loss_train: 0.1864, accuracy_train: 0.9430, loss_valid: 0.3222, accuracy_valid: 0.8936, 0.3748sec
# epoch: 110, loss_train: 0.1849, accuracy_train: 0.9434, loss_valid: 0.3177, accuracy_valid: 0.8966, 0.3691sec
# epoch: 111, loss_train: 0.1834, accuracy_train: 0.9429, loss_valid: 0.3171, accuracy_valid: 0.8981, 0.3616sec
# epoch: 112, loss_train: 0.1811, accuracy_train: 0.9443, loss_valid: 0.3183, accuracy_valid: 0.8966, 0.3700sec
# epoch: 113, loss_train: 0.1819, accuracy_train: 0.9442, loss_valid: 0.3179, accuracy_valid: 0.8958, 0.4019sec
# epoch: 114, loss_train: 0.1803, accuracy_train: 0.9455, loss_valid: 0.3165, accuracy_valid: 0.8973, 0.3780sec
# epoch: 115, loss_train: 0.1787, accuracy_train: 0.9453, loss_valid: 0.3174, accuracy_valid: 0.8951, 0.3620sec
# epoch: 116, loss_train: 0.1780, accuracy_train: 0.9456, loss_valid: 0.3162, accuracy_valid: 0.8988, 0.3630sec
# epoch: 117, loss_train: 0.1756, accuracy_train: 0.9463, loss_valid: 0.3175, accuracy_valid: 0.8973, 0.3719sec
# epoch: 118, loss_train: 0.1760, accuracy_train: 0.9459, loss_valid: 0.3164, accuracy_valid: 0.8966, 0.3720sec
# epoch: 119, loss_train: 0.1747, accuracy_train: 0.9469, loss_valid: 0.3169, accuracy_valid: 0.8973, 0.3682sec
# epoch: 120, loss_train: 0.1736, accuracy_train: 0.9480, loss_valid: 0.3206, accuracy_valid: 0.8936, 0.3790sec
# epoch: 121, loss_train: 0.1723, accuracy_train: 0.9489, loss_valid: 0.3159, accuracy_valid: 0.8988, 0.3620sec
# epoch: 122, loss_train: 0.1706, accuracy_train: 0.9490, loss_valid: 0.3178, accuracy_valid: 0.8951, 0.3610sec
# epoch: 123, loss_train: 0.1685, accuracy_train: 0.9497, loss_valid: 0.3171, accuracy_valid: 0.8981, 0.3822sec
# epoch: 124, loss_train: 0.1681, accuracy_train: 0.9495, loss_valid: 0.3175, accuracy_valid: 0.8958, 0.3691sec
# epoch: 125, loss_train: 0.1677, accuracy_train: 0.9495, loss_valid: 0.3172, accuracy_valid: 0.8981, 0.3700sec
# epoch: 126, loss_train: 0.1665, accuracy_train: 0.9515, loss_valid: 0.3156, accuracy_valid: 0.8973, 0.3815sec
# epoch: 127, loss_train: 0.1654, accuracy_train: 0.9521, loss_valid: 0.3176, accuracy_valid: 0.8958, 0.3600sec
# epoch: 128, loss_train: 0.1639, accuracy_train: 0.9522, loss_valid: 0.3169, accuracy_valid: 0.8966, 0.3730sec
# epoch: 129, loss_train: 0.1625, accuracy_train: 0.9526, loss_valid: 0.3172, accuracy_valid: 0.8943, 0.3760sec
# epoch: 130, loss_train: 0.1615, accuracy_train: 0.9521, loss_valid: 0.3181, accuracy_valid: 0.8958, 0.3670sec
# epoch: 131, loss_train: 0.1602, accuracy_train: 0.9532, loss_valid: 0.3169, accuracy_valid: 0.8981, 0.3700sec
# epoch: 132, loss_train: 0.1593, accuracy_train: 0.9533, loss_valid: 0.3179, accuracy_valid: 0.8958, 0.4009sec
# epoch: 133, loss_train: 0.1596, accuracy_train: 0.9539, loss_valid: 0.3216, accuracy_valid: 0.8921, 0.3680sec
# epoch: 134, loss_train: 0.1579, accuracy_train: 0.9534, loss_valid: 0.3169, accuracy_valid: 0.8943, 0.3620sec
# epoch: 135, loss_train: 0.1542, accuracy_train: 0.9552, loss_valid: 0.3174, accuracy_valid: 0.8958, 0.3843sec
# epoch: 136, loss_train: 0.1550, accuracy_train: 0.9565, loss_valid: 0.3154, accuracy_valid: 0.8973, 0.3641sec
# epoch: 137, loss_train: 0.1532, accuracy_train: 0.9555, loss_valid: 0.3173, accuracy_valid: 0.8936, 0.3783sec
# epoch: 138, loss_train: 0.1515, accuracy_train: 0.9562, loss_valid: 0.3169, accuracy_valid: 0.8928, 0.3620sec
# epoch: 139, loss_train: 0.1521, accuracy_train: 0.9561, loss_valid: 0.3161, accuracy_valid: 0.8958, 0.3680sec
# epoch: 140, loss_train: 0.1498, accuracy_train: 0.9581, loss_valid: 0.3158, accuracy_valid: 0.8951, 0.3570sec
# epoch: 141, loss_train: 0.1486, accuracy_train: 0.9588, loss_valid: 0.3168, accuracy_valid: 0.8951, 0.3720sec
# epoch: 142, loss_train: 0.1479, accuracy_train: 0.9586, loss_valid: 0.3169, accuracy_valid: 0.8981, 0.3710sec
# epoch: 143, loss_train: 0.1472, accuracy_train: 0.9576, loss_valid: 0.3194, accuracy_valid: 0.8951, 0.3840sec
# 学習データでの正解率:0.9576461769115442
# 評価データでの正解率:0.896551724137931
