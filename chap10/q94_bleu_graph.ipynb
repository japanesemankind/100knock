# %%
import numpy as np
import matplotlib.pyplot as plt

if __name__ == "__main__":
    x_range=0
    score_list=[]
    with open("q94_bleu_log.txt") as f:
        for line in f:
            bleu_score=line.split(" ")[2]
            x_range+=1
            score_list.append(float(bleu_score))
    x_axis=[x for x in range(1,x_range+1)]
    print(score_list)
    #left = np.array([1, 2, 3, 4, 5])
    #height = np.array([100, 300, 200, 500, 400])
    #plt.plot(left, height)
    
    
    plt.plot(x_axis, score_list)
    plt.show()
# Out:
# [3.4, 4.5, 5.0, 5.2, 5.4, 5.3, 5.4, 5.4, 5.3, 5.4, 5.4, 5.2, 5.3, 5.4, 5.3, 5.3, 5.3, 5.3, 5.3, 5.2, 5.2, 5.0, 5.0, 4.9, 4.9, 4.9, 4.8, 4.8, 4.7, 4.7, 4.7, 4.7, 4.7, 4.7, 4.6, 4.6, 4.5, 4.5, 4.4, 4.5]
